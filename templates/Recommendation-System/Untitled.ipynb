# %%
import pandas as pd

# %%
df = pd.read_csv("DeMatch.csv")
df
# Out:
#               0                                                  1  \
# 0      /bg/1/1/  dhṛtarāṣṭra uvācadharma-kṣetre kuru-kṣetresama...
# 1      /bg/1/2/  sañjaya uvācadṛṣṭvā tu pāṇḍavānīkaṁvyūḍhaṁ dur...
# 2      /bg/1/3/  paśyaitāṁ pāṇḍu-putrānāmācārya mahatīṁ camūmvy...
# 3      /bg/1/4/  atra śūrā maheṣv-āsābhīmārjuna-samā yudhiyuyud...
# 4      /bg/1/5/  dhṛṣṭaketuś cekitānaḥkāśirājaś ca vīryavānpuru...
# ...         ...                                                ...
# 13766   /iso/14  sambhūtiṁ ca vināśaṁ cayas tad vedobhayaḿ saha...
# 13767   /iso/15  hiraṇmayena pātreṇasatyasyāpihitaṁ mukhamtat t...
# 13768   /iso/16  pūṣann ekarṣe yama sūrya prājāpatyavyūha raśmī...
# 13769   /iso/17  vāyur anilam amṛtamathedaṁ bhasmāntaṁ śarīramo...
# 13770   /iso/18  agne naya supathā rāye asmānviśvāni deva vayun...
#
#                                                        2  \
# 0      DftarAzwra uvAcaDarma-kzetre kuru-kzetresamave...
# ...

# %%
df = pd.read_csv("edited_id.csv")
df
# Out:
#               0                                                  1  \
# 0      /bg/1/1/  dhṛtarāṣṭra uvācadharma-kṣetre kuru-kṣetresama...
# 1      /bg/1/2/  sañjaya uvācadṛṣṭvā tu pāṇḍavānīkaṁvyūḍhaṁ dur...
# 2      /bg/1/3/  paśyaitāṁ pāṇḍu-putrānāmācārya mahatīṁ camūmvy...
# 3      /bg/1/4/  atra śūrā maheṣv-āsābhīmārjuna-samā yudhiyuyud...
# 4      /bg/1/5/  dhṛṣṭaketuś cekitānaḥkāśirājaś ca vīryavānpuru...
# ...         ...                                                ...
# 13766   /iso/14  sambhūtiṁ ca vināśaṁ cayas tad vedobhayaḿ saha...
# 13767   /iso/15  hiraṇmayena pātreṇasatyasyāpihitaṁ mukhamtat t...
# 13768   /iso/16  pūṣann ekarṣe yama sūrya prājāpatyavyūha raśmī...
# 13769   /iso/17  vāyur anilam amṛtamathedaṁ bhasmāntaṁ śarīramo...
# 13770   /iso/18  agne naya supathā rāye asmānviśvāni deva vayun...
#
#                                                        2  \
# 0      DftarAzwra uvAcaDarma-kzetre kuru-kzetresamave...
# ...
