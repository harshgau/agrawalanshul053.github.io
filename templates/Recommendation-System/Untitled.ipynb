# %%
import pandas as pd

# %%
df = pd.read_csv("edited_id.csv")
df
for i in range(len(df)):
    print(i,df['0'][i])
# Out:
# 0 /bg/1/1/
# 1 /bg/1/2/
# 2 /bg/1/3/
# 3 /bg/1/4/
# 4 /bg/1/5/
# 5 /bg/1/6/
# 6 /bg/1/7/
# 7 /bg/1/8/
# 8 /bg/1/9/
# 9 /bg/1/10/
# 10 /bg/1/11/
# 11 /bg/1/12/
# 12 /bg/1/13/
# 13 /bg/1/14/
# 14 /bg/1/15/
# 15 /bg/1/16-18/
# 16 /bg/1/19/
# 17 /bg/1/20/
# 18 /bg/1/21-22/
# 19 /bg/1/23/
# 20 /bg/1/24/
# 21 /bg/1/25/
# 22 /bg/1/26/
# 23 /bg/1/27/
# 24 /bg/1/28/
# 25 /bg/1/29/
# 26 /bg/1/30/
# 27 /bg/1/31/
# 28 /bg/1/32-35/
# 29 /bg/1/36/
# 30 /bg/1/37-38/
# 31 /bg/1/39/
# 32 /bg/1/40/
# 33 /bg/1/41/
# 34 /bg/1/42/
# 35 /bg/1/43/
# 36 /bg/1/44/
# 37 /bg/1/45/
# 38 /bg/1/46/
# 39 /bg/1/46/
# 40 /bg/2/2/
# 41 /bg/2/3/
# 42 /bg/2/4/
# 43 /bg/2/5/
# 44 /bg/2/6/
# 45 /bg/2/7/
# 46 /bg/2/8/
# 47 /bg/2/9/
# 48 /bg/2/10/
# 49 /bg/2/11/
# 50 /bg/2/12/
# 51 /bg/2/13/
# 52 /bg/2/14/
# 53 /bg/2/15/
# 54 /bg/2/16/
# 55 /bg/2/17/
# 56 /bg/2/18/
# 57 /bg/2/19/
# 58 /bg/2/20/
# 59 /bg/2/21/
# 60 /bg/2/22/
# 61 /bg/2/23/
# 62 /bg/2/24/
# 63 /bg/2/25/
# 64 /bg/2/26/
# 65 /bg/2/27/
# 66 /bg/2/28/
# ...

# %%
# df = pd.read_csv("edited_id.csv")
df['9'][0]
# Out:
# "['/bg/4/5/', '/bg/14/27/', '/sb/1/5/6/', '/sb/1/7/27/', '/sb/2/10/9/', '/sb/3/7/29/', '/sb/3/29/25/', '/sb/4/29/51/', '/sb/5/10/5/', '/sb/5/14/46/', '/sb/5/17/21/', '/sb/5/18/36/', '/sb/5/19/17-18/', '/sb/5/20/16/', '/sb/6/4/25/', '/sb/6/12/15/', '/sb/7/9/47/', '/sb/8/1/9/', '/sb/8/3/26/', '/sb/8/3/29/', '/sb/9/8/7/', '/sb/10/28/13/', '/sb/10/32/21/', '/sb/10/84/24-25/', '/sb/11/3/43/', '/sb/11/12/22-23/', '/sb/11/14/3/', '/sb/11/29/49/', '/sb/12/4/42/', '/sb/12/9/6/', '/bs/5/28', '/bg/1/1/']"
